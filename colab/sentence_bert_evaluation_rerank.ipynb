# %% [markdown]
# #BERT development praparation
# Dense Retrieval using SBERT, ANCE, USE-QA or DPR

# %%
# !python -V
# !pip install beir tensorflow-text
# !python -V
# Out:
# Python 3.10.12
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 61.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 13.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 45.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.2/219.2 kB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 53.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 27.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 19.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 34.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# Reranking using Cross-Encoder model

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_rerank_playground.py -i scifact -m msmarco-distilbert-base-tas-b -r cross-encoder/ms-marco-electra-base
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 13:35:22.093315: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 13:35:24 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 92809.63it/s]
# 2023-07-01 13:35:24 - Loaded 5183 TEST Documents.
# ...

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_rerank_playground.py -i scifact -m msmarco-distilbert-base-tas-b -r cross-encoder/ms-marco-TinyBERT-L-2-v2
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 13:57:03.782878: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 13:57:04 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 79307.28it/s]
# 2023-07-01 13:57:04 - Loaded 5183 TEST Documents.
# ...

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_rerank_playground.py -i scifact -m msmarco-distilbert-base-tas-b -r cross-encoder/stsb-distilroberta-base
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 13:59:22.498562: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 13:59:23 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 95244.90it/s]
# 2023-07-01 13:59:23 - Loaded 5183 TEST Documents.
# ...

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_rerank_playground.py -i scifact -m msmarco-distilbert-base-tas-b -r cross-encoder/ms-marco-MiniLM-L-4-v2
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 14:10:16.274919: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 14:10:17 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 97662.90it/s]
# 2023-07-01 14:10:17 - Loaded 5183 TEST Documents.
# ...

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_rerank_playground.py -i scifact -m msmarco-distilbert-base-tas-b -r cross-encoder/ms-marco-MiniLM-L-6-v2
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 14:14:27.905893: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 14:14:29 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 90502.94it/s]
# 2023-07-01 14:14:29 - Loaded 5183 TEST Documents.
# ...

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_rerank_playground.py -i scifact -m msmarco-distilbert-base-tas-b -r cross-encoder/nli-deberta-v3-xsmall
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 14:19:50.843998: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 14:19:51 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 96898.48it/s]
# 2023-07-01 14:19:52 - Loaded 5183 TEST Documents.
# ...
