# %% [markdown]
# #BERT development praparation
# Dense Retrieval using SBERT, ANCE, USE-QA or DPR

# %%
# !python -V
# !pip install beir tensorflow-text
# !python -V
# Out:
# Python 3.10.12
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 42.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 61.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.2/219.2 kB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 37.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 14.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 24.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_playground.py -i scifact -m msmarco-distilbert-base-tas-b
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 06:00:57.538428: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 06:00:58 - Downloading scifact.zip ...
# /content/drive/MyDrive/Code/datasets/scifact.zip: 100% 2.69M/2.69M [00:01<00:00, 2.33MiB/s]
# 2023-07-01 06:01:01 - Unzipping scifact.zip ...
# 2023-07-01 06:01:01 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 99161.05it/s]
# 2023-07-01 06:01:01 - Loaded 5183 TEST Documents.
# ...

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_playground.py -i scifact -m distiluse-base-multilingual-cased-v2
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 06:12:47.683718: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 06:12:48 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 96182.52it/s]
# 2023-07-01 06:12:48 - Loaded 5183 TEST Documents.
# ...

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_playground.py -i scifact -m multi-qa-distilbert-cos-v1
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 06:43:28.566238: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 06:43:30 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 49324.15it/s]
# 2023-07-01 06:43:30 - Loaded 5183 TEST Documents.
# ...

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_playground.py -i scifact -m msmarco-distilbert-base-v3
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 06:45:59.251961: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 06:46:01 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 50153.60it/s]
# 2023-07-01 06:46:01 - Loaded 5183 TEST Documents.
# ...

# %% [markdown]
# Sparse

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_sparse_playground.py -i scifact -m BeIR/sparta-msmarco-distilbert-base-v1
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 06:51:26.371974: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 06:51:28 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 64329.74it/s]
# 2023-07-01 06:51:28 - Loaded 5183 TEST Documents.
# ...

# %% [markdown]
# Reranking using Cross-Encoder model

# %%
# %cd /content/drive/MyDrive/Code
# !python ir_rerank_playground.py -i scifact -m msmarco-distilbert-base-tas-b
# Out:
# /content/drive/MyDrive/Code
# 2023-07-01 07:36:19.179442: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-07-01 07:36:20 - Loading Corpus...
# 100% 5183/5183 [00:00<00:00, 51057.43it/s]
# 2023-07-01 07:36:21 - Loaded 5183 TEST Documents.
# ...
